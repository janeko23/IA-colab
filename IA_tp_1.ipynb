# %% [markdown]
# <a href="https://colab.research.google.com/github/janeko23/IA-colab/blob/main/IA_tp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Objetivo:
# Realizar un análisis de datos sobre distintos datasets y ver su distribución. Luego, analizar la
# técnica de Regresión Lineal y a partir de esta, obtener modelos que permitan predecir el
# comportamiento de variables.

# %% [markdown]
# #Desarrollo:
# 1. En base al dataset “**Iot_telemetry_data.csv**”, el cual muestra datos obtenidos a partir de
# sensores, realizar los siguientes estudios:
#
#   a. Media y desvío standard de Monóxido de Carbono, Humedad y temperatura.
#
#   b. Graficar de a pares a cada variable para estudiar las distintas relaciones entre ellas.
#
#   c. Analizar la distribución de Monóxido de Carbono y de Humedad, mediante histogramas. En base a este ítem y el anterior, estudiar los coeficientes de correlación.
#
#   d. Tomando en cuenta el punto anterior, analizar cuáles variables serían convenientes integrarlas en un modelo de Regresión Lineal y obtener dicho modelo.

# %% [markdown]
# #Preguntas:
# 1. ¿Cómo se podría construir un modelo de Regresión Lineal Múltiple?
# 2. Investigar los conceptos de Underfitting y Overfitting
#
# **Nota:** El dataset se puede obtener de Kaggle como “Environmental Sensor Telemetry Data”
#
# Mackdown: https://colab.research.google.com/notebooks/markdown_guide.ipynb

# %% [markdown]
# # Cargo las librerias a usar

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt   #Data visualisation libraries 
import scipy as sc
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# *Cargamos el dataset*

# %%
# Load dataset
url = "gitlab.com/Inteligencia_Artificial_UNDAV/trabajos_laboratorio/-/blob/20509cdc383115d5b8a446f3a4e040c57ce7bf0c/TL_N%C2%B01/iot_telemetry_data.csv"
dataset = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-8527d4b8eda7> in <module>()
#       1 # Load dataset
#       2 url = "gitlab.com/Inteligencia_Artificial_UNDAV/trabajos_laboratorio/-/blob/20509cdc383115d5b8a446f3a4e040c57ce7bf0c/TL_N%C2%B01/iot_telemetry_data.csv"
# ----> 3 dataset = pd.read_csv(url)
#
# ...

# %%
# head
dataset.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="YT0RQPlriJZXjw514+XVJg">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>iot_telemetry_data.csv - Google 雲端硬碟</title><meta property="og:title" content="iot_telemetry_data.csv"><meta property="og:type" content="article"><meta property="
# ...

# %%
url = "/content/drive/MyDrive/IA/iot_telemetry_data.csv"
DfViejo = pd.read_csv(url)
dfNuevo = pd.DataFrame()
dfNuevo['Monóxido de Carbono'] = DfViejo['co']
dfNuevo['Humedad'] = DfViejo['humidity']
dfNuevo['Temperatura'] = DfViejo['temp']
dfNuevo.describe()
# Out:
#        Monóxido de Carbono        Humedad    Temperatura
# count        405184.000000  405184.000000  405184.000000
# mean              0.004639      60.511694      22.453987
# std               0.001250      11.366489       2.698347
# min               0.001171       1.100000       0.000000
# 25%               0.003919      51.000000      19.900000
# 50%               0.004812      54.900000      22.200000
# 75%               0.005409      74.300003      23.600000
# max               0.014420      99.900002      30.600000

# %%
sns.pairplot(dfNuevo)

# %%
sns.distplot(dfNuevo['Monóxido de Carbono']).set_title('Monóxido de Carbono')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Monóxido de Carbono')

# %%
sns.distplot(dfNuevo['Humedad']).set_title("Histogram for Humedad")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Histogram for Humedad')

# %%
sns.distplot(dfNuevo['Temperatura']).set_title("Histogram for Temperatura")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Histogram for Temperatura')

# %%
sns.displot(dfNuevo, kde = False)
plt.title("Histogram for Temperatura")
plt.show()
